# %%
import spacy

# %%
spacy.cli.download("es_core_news_sm") # Se requiere ejecutarlo solo la primera vez

# %%
spacy.load("es_core_news_sm") # Necesario cargarlo al programar

# %%
texto = "Hola a todos ¿Cómo están? Hoy aprenderemos Spacy"

# %%
nlp = spacy.load("es_core_news_sm")

# %%
tokens = nlp(texto.lower()) #procesamos nuestro texto
print([t for t in tokens])
# Out:
# [hola, a, todos, ¿, cómo, están, ?, hoy, aprenderemos, spacy]

# %%
print([(t.text, t.lemma_) for t in tokens]) #lematización
# Out:
# [('hola', 'hola'), ('a', 'a'), ('todos', 'todo'), ('¿', '¿'), ('cómo', 'cómo'), ('están', 'estar'), ('?', '?'), ('hoy', 'hoy'), ('aprenderemos', 'aprender'), ('spacy', 'spacy')]

# %%
print([(t.text, t.tag_) for t in tokens]) #etiquetado gramatical (POS TAGGING)
# Out:
# [('hola', 'VERB'), ('a', 'ADP'), ('todos', 'DET'), ('¿', 'PUNCT'), ('cómo', 'PRON'), ('están', 'VERB'), ('?', 'PUNCT'), ('hoy', 'ADV'), ('aprenderemos', 'VERB'), ('spacy', 'NOUN')]

# %%
texto2 = "El instructor Jesús Romero Villanueva, dictará un curso en SENATI en la ciudad de Arequipa"

# %%
tokens =nlp(texto2)

# %%
for t in tokens.ents: #RECONOCIMIENDTO DE INDETIFICADORES
    print(t)
# Out:
# Jesús Romero Villanueva
# SENATI
# Arequipa

# %%
print("MEMENTO MORI")
# Out:
# MEMENTO MORI

# %%
tokens = nlp(texto2.lower()) #procesamos nuestro texto
print([t for t in tokens])
# Out:
# [el, instructor, jesús, romero, villanueva, ,, dictará, un, curso, en, senati, en, la, ciudad, de, arequipa]

# %%
for t in tokens:
    print([t])
# Out:
# [el]
# [instructor]
# [jesús]
# [romero]
# [villanueva]
# [,]
# [dictará]
# [un]
# [curso]
# [en]
# [senati]
# [en]
# [la]
# [ciudad]
# [de]
# [arequipa]

# %%
print([(t.text, t.lemma_) for t in tokens]) #lematización
# Out:
# [('el', 'el'), ('instructor', 'instructor'), ('jesús', 'jesús'), ('romero', 'romero'), ('villanueva', 'villanueva'), (',', ','), ('dictará', 'dictar'), ('un', 'uno'), ('curso', 'curso'), ('en', 'en'), ('senati', 'senati'), ('en', 'en'), ('la', 'el'), ('ciudad', 'ciudad'), ('de', 'de'), ('arequipa', 'arequipa')]

# %%
for t in tokens:
    print([t.text, t.lemma_])
# Out:
# ['el', 'el']
# ['instructor', 'instructor']
# ['jesús', 'jesús']
# ['romero', 'romero']
# ['villanueva', 'villanueva']
# [',', ',']
# ['dictará', 'dictar']
# ['un', 'uno']
# ['curso', 'curso']
# ['en', 'en']
# ['senati', 'senati']
# ['en', 'en']
# ['la', 'el']
# ['ciudad', 'ciudad']
# ['de', 'de']
# ['arequipa', 'arequipa']

# %%
print([(t.text, t.tag_) for t in tokens]) #etiquetado gramatical (POS TAGGING)
# Out:
# [('el', 'DET'), ('instructor', 'NOUN'), ('jesús', 'PROPN'), ('romero', 'PROPN'), ('villanueva', 'PROPN'), (',', 'PUNCT'), ('dictará', 'VERB'), ('un', 'DET'), ('curso', 'NOUN'), ('en', 'ADP'), ('senati', 'PROPN'), ('en', 'ADP'), ('la', 'DET'), ('ciudad', 'NOUN'), ('de', 'ADP'), ('arequipa', 'NOUN')]

# %%
for t in tokens:
    print([t.text, t.tag_])
# Out:
# ['el', 'DET']
# ['instructor', 'NOUN']
# ['jesús', 'PROPN']
# ['romero', 'PROPN']
# ['villanueva', 'PROPN']
# [',', 'PUNCT']
# ['dictará', 'VERB']
# ['un', 'DET']
# ['curso', 'NOUN']
# ['en', 'ADP']
# ['senati', 'PROPN']
# ['en', 'ADP']
# ['la', 'DET']
# ['ciudad', 'NOUN']
# ['de', 'ADP']
# ['arequipa', 'NOUN']
